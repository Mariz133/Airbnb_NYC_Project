# %% [markdown]
# **Name** Mariam Riaz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airbnb_NYC = pd.read_csv('AB_NYC_2019.csv')
airbnb_NYC
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
airbnb_NYC.shape
# Out:
# (48895, 16)

# %%
airbnb_NYC.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
airbnb_NYC['last_review'] = pd.to_datetime(airbnb_NYC['last_review'])
airbnb_NYC.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %%
print(airbnb_NYC['last_review'].min())
print(airbnb_NYC['last_review'].max())
# Out:
# 2011-03-28 00:00:00
# 2019-07-08 00:00:00

# %%
airbnb_NYC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  datetime64[ns]
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 6.0+ MB

# %%
airbnb_NYC.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# top              Manhattan  Williamsburg           NaN           NaN
# freq                 21661          3920           NaN           NaN
# mean                   NaN           NaN     40.728949    -73.952170
# min                    NaN           NaN     40.499790    -74.244420
# 25%                    NaN           NaN     40.690100    -73.983070
# 50%                    NaN           NaN     40.723070    -73.955680
# 75%                    NaN           NaN     40.763115    -73.936275
# max                    NaN           NaN     40.913060    -73.712990
# std                    NaN           NaN      0.054530      0.046157
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             48895  48895.000000    48895.000000       48895.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq              25409           NaN             NaN                NaN
# mean                NaN    152.720687        7.029962          23.274466
# min                 NaN      0.000000        1.000000           0.000000
# 25%                 NaN     69.000000        1.000000           1.000000
# 50%                 NaN    106.000000        3.000000           5.000000
# 75%                 NaN    175.000000        5.000000          24.000000
# max                 NaN  10000.000000     1250.000000         629.000000
# std                 NaN    240.154170       20.510550          44.550582
#
#                           last_review  reviews_per_month  \
# count                           38843       38843.000000
# unique                            NaN                NaN
# top                               NaN                NaN
# freq                              NaN                NaN
# mean    2018-10-04 01:47:23.910099456           1.373221
# min               2011-03-28 00:00:00           0.010000
# 25%               2018-07-08 00:00:00           0.190000
# 50%               2019-05-19 00:00:00           0.720000
# 75%               2019-06-23 00:00:00           2.020000
# max               2019-07-08 00:00:00          58.500000
# std                               NaN           1.680442
#
#         calculated_host_listings_count  availability_365
# count                     48895.000000      48895.000000
# unique                             NaN               NaN
# top                                NaN               NaN
# freq                               NaN               NaN
# mean                          7.143982        112.781327
# min                           1.000000          0.000000
# 25%                           1.000000          0.000000
# 50%                           1.000000         45.000000
# 75%                           2.000000        227.000000
# max                         327.000000        365.000000
# std                          32.952519        131.622289

# %%
display(airbnb_NYC[airbnb_NYC['minimum_nights']  > 365] [['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
# Out:
#                                       name   host_name neighbourhood_group  \
# 1305   800sqft apartment with huge terrace  Alessandra            Brooklyn
# 2854                                   NaN       Peter           Manhattan
# 5767      Prime W. Village location 1 bdrm   Genevieve           Manhattan
# 7355   Beautiful Fully Furnished 1 bed/bth       Aliya              Queens
# 8014             Wonderful Large 1 bedroom        John           Manhattan
# 10829  Brand New Luxury Apt Lease Takeover     Shining              Queens
# 11193   Zen Room in Crown Heights Brooklyn       Laura            Brooklyn
# 13404   Historic Designer 2 Bed. Apartment    Glenn H.           Manhattan
# 14285      Peaceful apartment close to F/G      Amanda            Brooklyn
# 15946   Bright Luxury Studio, Central Loc.       Sarah           Manhattan
# 26341      Beautiful place in Brooklyn! #2       Angie            Brooklyn
# 34487                        Not available         Sol            Brooklyn
# 38664         Shared Studio (females only)         Meg           Manhattan
# 47620               Williamsburg Apartment         Meg            Brooklyn
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 1305   Entire home/apt    115             370                  6
# 2854   Entire home/apt    400            1000                  0
# 5767   Entire home/apt    180            1250                  2
# 7355   Entire home/apt    134             500                 30
# 8014   Entire home/apt     75             500                  0
# 10829  Entire home/apt    199             480                  0
# 11193     Private room     50             500                 10
# 13404  Entire home/apt     99             999                  2
# 14285     Private room     45             500                  0
# 15946  Entire home/apt    250             366                  0
# 26341     Private room     79             999                 24
# 34487     Private room     50             400                  0
# 38664      Shared room    110             999                  0
# 47620  Entire home/apt    140             500                  0
#
#        availability_365
# 1305                365
# 2854                362
# 5767                365
# 7355                 90
# 8014                362
# 10829               365
# 11193               365
# 13404                42
# 14285               358
# 15946               365
# 26341               249
# 34487                90
# 38664               365
# 47620               331

# %%
print("Listings with a price of $0:")
#display(df[df['price'] == 0][['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
display(airbnb_NYC[airbnb_NYC['price'] == 0] [['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
# Out:
# Listings with a price of $0:
#                                                     name     host_name  \
# 23161  Huge Brooklyn Brownstone Living, Close to it all.      Kimberly
# 25433      ★Hostel Style Room | Ideal Traveling Buddies★        Anisha
# 25634    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)  Martial Loft
# 25753                    Sunny, Quiet Room in Greenpoint        Lauren
# 25778      Modern apartment in the heart of Williamsburg       Aymeric
# 25794  Spacious comfortable master bedroom with nice ...       Adeyemi
# 25795  Contemporary bedroom in brownstone with nice view       Adeyemi
# 25796       Cozy yet spacious private brownstone bedroom       Adeyemi
# 26259                              the best you can find        Qiuchi
# 26841  Coliving in Brooklyn! Modern design / Shared room        Sergii
# 26866             Best Coliving space ever! Shared room.        Sergii
#
#       neighbourhood_group        room_type  price  minimum_nights  \
# 23161            Brooklyn     Private room      0               4
# 25433               Bronx     Private room      0               2
# 25634            Brooklyn     Private room      0               2
# 25753            Brooklyn     Private room      0               2
# 25778            Brooklyn  Entire home/apt      0               5
# 25794            Brooklyn     Private room      0               1
# 25795            Brooklyn     Private room      0               1
# 25796            Brooklyn     Private room      0               1
# 26259           Manhattan  Entire home/apt      0               3
# 26841            Brooklyn      Shared room      0              30
# 26866            Brooklyn      Shared room      0              30
#
#        number_of_reviews  availability_365
# 23161                  1                28
# 25433                 55               127
# 25634                 16                 0
# 25753                 12                 0
# 25778                  3                73
# 25794                 93               176
# 25795                 95               232
# 25796                 95               222
# 26259                  0                 0
# 26841                  2               333
# 26866                  5               139

# %%
print("Listings with a price of less than $10:")
#display(df[df['price'] == 10][['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
display(airbnb_NYC[airbnb_NYC['price'] == 10][['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
# Out:
# Listings with a price of less than $10:
#                                                     name          host_name  \
# 2860       Large furnished 2 bedrooms- - 30 days Minimum              Sally
# 21700               Couch in Harlem Harvey Refugees only             Morgan
# 22261  Newly renovated, fully furnished room in Brooklyn              Katie
# 22287                                            Jen Apt           Jennifer
# 22835                            IT'S SIMPLY CONVENIENT!              Maria
# 23256             Quiet, Cozy UES Studio Near the Subway                Amy
# 24100  Girls only, cozy room one block from Times Square              Mario
# 27972      Spacious 2-bedroom Apt in Heart of Greenpoint  Vishanti & Jeremy
# 31066    Very Spacious bedroom, steps from CENTRAL PARK.              Salim
# 31407                           Cozy feel at home studio            Maureen
# 32810  Gigantic Sunny Room in Park Slope-Private Back...             Rachel
# 33225                             Voted #1 Airbnb In NYC              Maria
# 33505                                   Room with a view             Martin
# 34446                                        Bronx Apart                Luz
# 35386                 Cozy room in a three-bedroom House             Arthur
# 35601       Charming, bright and brand new Bed-Stuy home           Caterina
# 47218                         Beautiful room in Bushwick              Julio
#
#       neighbourhood_group        room_type  price  minimum_nights  \
# 2860            Manhattan  Entire home/apt     10              30
# 21700           Manhattan      Shared room     10               1
# 22261            Brooklyn     Private room     10               5
# 22287           Manhattan     Private room     10               5
# 22835              Queens  Entire home/apt     10               1
# 23256           Manhattan  Entire home/apt     10               3
# 24100           Manhattan      Shared room     10               1
# 27972            Brooklyn  Entire home/apt     10               1
# 31066           Manhattan     Private room     10               1
# 31407           Manhattan     Private room     10               5
# 32810            Brooklyn  Entire home/apt     10               1
# 33225              Queens  Entire home/apt     10               2
# 33505            Brooklyn     Private room     10               1
# 34446               Bronx     Private room     10               1
# 35386              Queens     Private room     10               7
# 35601            Brooklyn  Entire home/apt     10               3
# 47218            Brooklyn     Private room     10               1
#
#        number_of_reviews  availability_365
# 2860                   0               137
# 21700                  0                 0
# 22261                  0                 0
# 22287                  2                 0
# 22835                 43               252
# 23256                 10                 0
# 24100                  2                 0
# 27972                 93                32
# 31066                  2                 0
# 31407                 42                 2
# 32810                 14                 4
# 33225                 22               332
# 33505                  0                83
# 34446                  0               180
# 35386                  4               180
# 35601                  5                 0
# 47218                  2                 0

# %%
print("Listings with a price of $10,000:")
#display(df[df['price'] == 10000][['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
display(airbnb_NYC[airbnb_NYC['price'] == 10000] [['name', 'host_name', 'neighbourhood_group', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'availability_365']])
# Out:
# Listings with a price of $10,000:
#                                                   name host_name  \
# 9151               Furnished room in Astoria apartment  Kathrine
# 17692  Luxury 1 bedroom apt. -stunning Manhattan views      Erin
# 29238                              1-BR Lincoln Center    Jelena
#
#       neighbourhood_group        room_type  price  minimum_nights  \
# 9151               Queens     Private room  10000             100
# 17692            Brooklyn  Entire home/apt  10000               5
# 29238           Manhattan  Entire home/apt  10000              30
#
#        number_of_reviews  availability_365
# 9151                   2                 0
# 17692                  5                 0
# 29238                  0                83

# %%
# Remove rows where price is 0
#price is 0, which is illogical for a listing
airbnb_NYC = airbnb_NYC[airbnb_NYC['price'] > 0]
airbnb_NYC.shape
# Out:
# (48884, 16)

# %%
#Remove extreme minimum_nights outliers
airbnb_NYC = airbnb_NYC[airbnb_NYC['minimum_nights'] <= 365]
airbnb_NYC.shape
# Out:
# (48870, 16)

# %%
airbnb_NYC.isnull().sum()
# Out:
# id                                    0
# name                                 15
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10043
# reviews_per_month                 10043
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airbnb_NYC['name'].fillna('Unknown', inplace=True)
airbnb_NYC['host_name'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_428/1499402464.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_NYC['name'].fillna('Unknown', inplace=True)
# /tmp/ipykernel_428/1499402464.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_NYC['host_name'].fillna('Unknown', inplace=True)

# %%
airbnb_NYC['last_review'].fillna('No reviews', inplace=True)
airbnb_NYC['reviews_per_month'].fillna(0, inplace=True)
# Out:
# /tmp/ipykernel_428/3954592106.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_NYC['last_review'].fillna('No reviews', inplace=True)
# /tmp/ipykernel_428/3954592106.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'No reviews' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   airbnb_NYC['last_review'].fillna('No reviews', inplace=True)
# /tmp/ipykernel_428/3954592106.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_NYC['reviews_per_month'].fillna(0, inplace=True)

# %%
airbnb_NYC.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
airbnb_NYC.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.887000e+04           48870  4.887000e+04     48870
# unique           NaN           47884           NaN     11449
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901848e+07             NaN  6.762985e+07       NaN
# std     1.098393e+07             NaN  7.862005e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.472371e+06             NaN  7.821708e+06       NaN
# 50%     1.967676e+07             NaN  3.080150e+07       NaN
# 75%     2.915342e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48870         48870  48870.000000  48870.000000
# unique                   5           221           NaN           NaN
# top              Manhattan  Williamsburg           NaN           NaN
# freq                 21654          3917           NaN           NaN
# mean                   NaN           NaN     40.728952    -73.952172
# std                    NaN           NaN      0.054534      0.046163
# min                    NaN           NaN     40.499790    -74.244420
# 25%                    NaN           NaN     40.690092    -73.983080
# 50%                    NaN           NaN     40.723080    -73.955690
# 75%                    NaN           NaN     40.763127    -73.936280
# max                    NaN           NaN     40.913060    -73.712990
#
#               room_type         price  minimum_nights  number_of_reviews  \
# count             48870  48870.000000    48870.000000       48870.000000
# unique                3           NaN             NaN                NaN
# top     Entire home/apt           NaN             NaN                NaN
# freq              25398           NaN             NaN                NaN
# mean                NaN    152.759402        6.840311          23.277143
# std                 NaN    240.199363       16.453077          44.556389
# min                 NaN     10.000000        1.000000           0.000000
# 25%                 NaN     69.000000        1.000000           1.000000
# 50%                 NaN    106.000000        3.000000           5.000000
# 75%                 NaN    175.000000        5.000000          24.000000
# max                 NaN  10000.000000      365.000000         629.000000
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count        48870       48870.000000                    48870.000000
# unique        1765                NaN                             NaN
# top     No reviews                NaN                             NaN
# freq         10043                NaN                             NaN
# mean           NaN           1.091070                        7.146286
# std            NaN           1.597354                       32.960753
# min            NaN           0.000000                        1.000000
# 25%            NaN           0.040000                        1.000000
# 50%            NaN           0.370000                        1.000000
# 75%            NaN           1.580000                        2.000000
# max            NaN          58.500000                      327.000000
#
#         availability_365
# count       48870.000000
# unique               NaN
# top                  NaN
# freq                 NaN
# mean          112.728443
# std           131.596499
# min             0.000000
# 25%             0.000000
# 50%            45.000000
# 75%           227.000000
# max           365.000000

# %%
airbnb_NYC.duplicated().sum()
# Out:
# np.int64(0)

# %%
airbnb_NYC['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25398
# Private room       22315
# Shared room         1157
# Name: count, dtype: int64

# %%
airbnb_NYC['room_type'].value_counts().plot(kind='bar')
plt.title('Room Type Distribution')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.savefig('room_type_distribution.png')
plt.show()

# %%
airbnb_NYC['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21654
# Brooklyn         20089
# Queens            5664
# Bronx             1090
# Staten Island      373
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=airbnb_NYC, x='neighbourhood_group')
plt.title('Distribution of Neighbourhood Groups')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')
plt.savefig('neighbourhood_group_distribution.png')
plt.show()

# %%
airbnb_NYC['price'].value_counts()
# Out:
# price
# 100     2051
# 150     2047
# 50      1532
# 60      1458
# 200     1401
#         ...
# 580        1
# 659        1
# 381        1
# 1900       1
# 338        1
# Name: count, Length: 673, dtype: int64

# %%
plt.figure(figsize=(8,5))
airbnb_NYC['price'].hist(bins=50, color='green', edgecolor='black')
plt.title("Distribution of Airbnb Prices in NYC")
plt.xlabel("Price ($)")
plt.ylabel('Number of Listings')
plt.xlim(0, 1000)  # limit extreme outliers for clarity
plt.savefig('price_distribution.png')
plt.show()

# %%
airbnb_NYC['number_of_reviews'].value_counts()
# Out:
# number_of_reviews
# 0      10043
# 1       5243
# 2       3462
# 3       2519
# 4       1994
#        ...
# 372        1
# 299        1
# 436        1
# 310        1
# 341        1
# Name: count, Length: 394, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.hist(airbnb_NYC['number_of_reviews'], bins=50, color='salmon', edgecolor='black')
plt.title("Distribution of Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Frequency")
plt.xlim(0, 200)  # limit extreme outliers
plt.savefig('number_of_reviews_distribution.png')
plt.show()

# %%
airbnb_NYC['availability_365'].value_counts()
# Out:
# availability_365
# 0      17530
# 365     1289
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: count, Length: 366, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.hist(airbnb_NYC['availability_365'], bins=50, color='orange', edgecolor='black')
plt.title("Availability of Listings During the Year")
plt.xlabel("Days Available")
plt.ylabel("Number of Listings")
plt.xlim(0, 365)  # limit extreme outliers
plt.savefig('availability_distribution.png')
plt.show()

# %%
airbnb_NYC['minimum_nights'].value_counts().sort_index()
# Out:
# minimum_nights
# 1      12717
# 2      11693
# 3       7998
# 4       3302
# 5       3033
#        ...
# 300        6
# 354        1
# 360        5
# 364        1
# 365       29
# Name: count, Length: 101, dtype: int64

# %%
airbnb_NYC['minimum_nights'].hist(bins=50, color='purple', edgecolor='black')
plt.title("Distribution of Minimum Nights")
plt.xlabel("Minimum Nights")
plt.ylabel("Number of Listings")
plt.xlim(0, 365)  # limit extreme outliers
plt.savefig('minimum_nights_distribution.png')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=airbnb_NYC, x='number_of_reviews', y='price', color='purple')
plt.title("Price vs Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Price ($)")
plt.savefig('price_vs_reviews.png')
plt.show()

# %%
plt.figure(figsize=(8,5))
airbnb_NYC.boxplot(column='price', by='room_type')
plt.title("Price by Room Type")
plt.suptitle("")  # removes automatic 'Boxplot grouped by' title
plt.xlabel("Room Type")
plt.ylabel("Price ($)")
#plt.ylim(0, 1000)  # ignore extreme outliers
plt.savefig('price_by_room_type.png')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='neighbourhood_group', y='price', data=airbnb_NYC, hue='neighbourhood_group', palette='pastel')
plt.title("Price Distribution by Neighbourhood Group")
plt.xlabel("Neighbourhood Group")
plt.ylabel("Price ($)")
plt.savefig('price_by_neighbourhood_group.png')
plt.show()

# %%
listings_under_30 = airbnb_NYC[airbnb_NYC['price'] <= 30]
print(f"Total number of listings under $30: {len(listings_under_30)}")
# Out:
# Total number of listings under $30: 648

# %%
entire_apt_under_100 = airbnb_NYC[(airbnb_NYC['room_type'] == 'Entire home/apt') & (airbnb_NYC['price'] <= 100)]
print(f"Total number of entire apartment listings under $100: {len(entire_apt_under_100)}")
# Out:
# Total number of entire apartment listings under $100: 4570
